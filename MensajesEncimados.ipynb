# %%
# !mkdir -p pruebas

# %%
# %%file pruebas/genera_json.c
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <unistd.h>
#
# // Recibe como argumetno la cantidad de mensajes a enviar
# // por defecto son 100. El máximo son 200 y el mínumo 1
# int main(int argc, char **argv) {
#     int i, x, y, cantidad;
#     char buffer[500];
#
#     srand(getpid());
#
#     if (argc < 2) {
#         cantidad = 100;
#     } else {
#         cantidad = atoi(argv[1]);
#         if ((cantidad < 1) || (cantidad > 1000)) {
#             cantidad = 100;
#         }
#     }
#
#     for (i=0; i<cantidad; i++) {
#         x = rand() % 500;
#         y = rand() % 500;
#         sprintf(buffer, "{\"numero\": %d, \"x\": %d, \"y\": %d}\n",
#                 1 + (rand() % 3), x, y);
#         //fprintf(stderr, "Mensaje %i\n", i);
#         printf("%s", buffer);
#         fflush(stdout);
#     }
# }
# Out:
# Overwriting pruebas/genera_json.c

# %%
# !gcc pruebas/genera_json.c -o pruebas/genera_json

# %%
# !./pruebas/genera_json 2 | nc localhost 4455
# Out:
# random: not enough state (4 bytes); ignored.

# %% [markdown]
# # Separar por `{` y `}`

# %%
# !lsof -i TCP:4455 | grep LISTEN | awk '{print $2}' | xargs kill

# %%
# coding: utf-8

from Queue import Queue


class SeparaJSON(object):
    """Maquina de pila estados para separar los paquetes, basados en la
    cantidad de llaves"""

    # Estados
    ESPERO_APERTURA = 'ESPERO_APERTURA'
    ABIERTO = 'ABIERTO'

    def __init__(self):
        """Constructor"""
        # Almacenamiento temporal
        self.buff = ''
        self.estado = self.ESPERO_APERTURA
        self.cantidad_llaves = 0
        self.mensajes = Queue()

    def procesar(self, data):
        """Procesa una cadena de entrada (de caracter a caracter)"""
        for c in data:
            self.procesar_char(c)

    def procesar_char(self, c):
        """Procesa un caracter de entrad"""

        if self.estado == self.ESPERO_APERTURA:
            if c == '{':
                self.estado = self.ABIERTO
                self.cantidad_llaves += 1
                self.buff += c
            else:
                pass  # Descarte
        elif self.estado == self.ABIERTO:
            if c == '}':
                self.cantidad_llaves -= 1
                self.buff += c
                if self.cantidad_llaves == 0:
                    # Mensaje completo, se desapilaron todas las llaves
                    self.mensajes.put(self.buff)
                    print self.buff
                    self.buff = ''
                    self.estado = self.ESPERO_APERTURA
            elif c == '{':
                self.cantidad_llaves += 1
                self.buff += c
            else:
                self.buff += c

    def disponible(self):
        return not self.mensajes.empty()

    def siguiente(self):
        """Devuelve el próximo mensaje"""
        return self.mensajes.get()

    def __iter__(self):
        """Iterador para for"""
        return IterQueue(self.mensajes)


class IterQueue(object):
    def __init__(self, q):
        self.q = q

    def next(self):
        if self.q.empty():
            raise StopIteration()
        return self.q.get()

# %%
from socket import socket
import json
from time import sleep
from subprocess import call
from time import time
import signal
import os
from multiprocessing import Process
import sys

PUERTO = 4455

def generar_json_y_pasar_por_netcat():
    sleep(0.5)
    print "Lanzando C"
    call("./pruebas/genera_json 200 | nc localhost %d" % PUERTO, shell=True)

def escuchar_conexiones():
    conexion = None
    def terminar():
        # Evitar el Error ADDRESS ALREADY IN USE
        conexion.shutdown(socket.SHUT_RDWR)
        conexion.close()
        sys.exit()   # Terminar el proceso
        
    signal.signal(signal.SIGTERM, terminar)
    conexion = socket()
    conexion.bind(('', 4455))
    conexion.listen(10)
    sock, addr = conexion.accept()
    errores, oks = 0, 0
    

    separador = SeparaJSON()
    
    while True:
        data = sock.recv(100)
        if not data:
            print "Socket Cerrado, finalizando!"
            print "OK=%d ERRORES=%d" % (oks, errores)
            break

        separador.procesar(data)
        
        for m in separador:
            try:
                json.loads(m)
            except ValueError:
                print "Error en JSON: %s" % m
                errores += 1
            else:
                oks += 1
            
p1 = Process(target=generar_json_y_pasar_por_netcat)
p2 = Process(target=escuchar_conexiones)
p2.start()
p1.start()
sleep(1)
p1.terminate()
p2.terminate()
# Out:
# Lanzando C
# {"numero": 1, "x": 383, "y": 386}
# {"numero": 2, "x": 415, "y": 293}
# {"numero": 1, "x": 386, "y": 492}
# {"numero": 2, "x": 421, "y": 362}
# {"numero": 3, "x": 190, "y": 59}
# {"numero": 1, "x": 426, "y": 40}
# {"numero": 3, "x": 172, "y": 236}
# {"numero": 1, "x": 368, "y": 67}
# {"numero": 3, "x": 282, "y": 30}
# {"numero": 2, "x": 123, "y": 67}
# {"numero": 1, "x": 429, "y": 302}
# {"numero": 1, "x": 58, "y": 69}
# {"numero": 2, "x": 393, "y": 456}
# {"numero": 1, "x": 42, "y": 229}
# {"numero": 3, "x": 421, "y": 419}
# {"numero": 3, "x": 37, "y": 198}
# {"numero": 3, "x": 315, "y": 370}
# {"numero": 3, "x": 26, "y": 91}
# {"numero": 3, "x": 456, "y": 373}
# {"numero": 2, "x": 170, "y": 496}
# {"numero": 3, "x": 305, "y": 425}
# {"numero": 3, "x": 327, "y": 336}
# {"numero": 2, "x": 346, "y": 229}
# {"numero": 1, "x": 357, "y": 124}
# {"numero": 3, "x": 82, "y": 45}
# {"numero": 3, "x": 367, "y": 434}
# {"numero": 2, "x": 43, "y": 250}
# {"numero": 3, "x": 308, "y": 276}
# {"numero": 1, "x": 288, "y": 84}
# {"numero": 2, "x": 151, "y": 254}
# {"numero": 3, "x": 432, "y": 60}
# {"numero": 2, "x": 368, "y": 239}
# {"numero": 1, "x": 226, "y": 86}
# {"numero": 2, "x": 39, "y": 295}
# {"numero": 3, "x": 434, "y": 378}
# {"numero": 3, "x": 101, "y": 97}
# {"numero": 2, "x": 317, "y": 492}
# {"numero": 3, "x": 256, "y": 301}
# {"numero": 1, "x": 286, "y": 441}
# {"numero": 3, "x": 189, "y": 444}
# {"numero": 1, "x": 440, "y": 229}
# {"numero": 3, "x": 117, "y": 97}
# {"numero": 1, "x": 481, "y": 175}
# {"numero": 2, "x": 427, "y": 67}
# {"numero": 1, "x": 497, "y": 353}
# {"numero": 3, "x": 465, "y": 306}
# {"numero": 2, "x": 219, "y": 124}
# {"numero": 3, "x": 371, "y": 232}
# {"numero": 1, "x": 3, "y": 19}
# {"numero": 3, "x": 368, "y": 208}
# {"numero": 1, "x": 340, "y": 149}
# {"numero": 2, "x": 223, "y": 118}
# {"numero": 2, "x": 346, "y": 451}
# {"numero": 2, "x": 55, "y": 379}
# {"numero": 2, "x": 264, "y": 228}
# {"numero": 2, "x": 350, "y": 193}
# {"numero": 1, "x": 34, "y": 264}
# {"numero": 3, "x": 414, "y": 487}
# {"numero": 3, "x": 243, "y": 491}
# {"numero": 2, "x": 365, "y": 359}
# {"numero": 3, "x": 432, "y": 51}
# {"numero": 3, "x": 228, "y": 275}
# {"numero": 3, "x": 474, "y": 121}
# {"numero": 2, "x": 395, "y": 29}
# {"numero": 3, "x": 235, "y": 293}
# {"numero": 1, "x": 428, "y": 143}
# {"numero": 3, "x": 428, "y": 29}
# {"numero": 2, "x": 404, "y": 443}
# {"numero": 3, "x": 113, "y": 38}
# {"numero": 2, "x": 340, "y": 404}
# {"numero": 1, "x": 128, "y": 188}
# {"numero": 1, "x": 417, "y": 417}
# {"numero": 1, "x": 324, "y": 243}
# {"numero": 3, "x": 183, "y": 490}
# {"numero": 2, "x": 272, "y": 225}
# {"numero": 3, "x": 90, "y": 5}
# {"numero": 1, "x": 454, "y": 286}
# {"numero": 3, "x": 82, "y": 42}
# {"numero": 1, "x": 197, "y": 7}
# {"numero": 3, "x": 304, "y": 348}
# {"numero": 3, "x": 122, "y": 328}
# {"numero": 3, "x": 343, "y": 246}
# {"numero": 3, "x": 340, "y": 422}
# {"numero": 2, "x": 310, "y": 105}
# {"numero": 2, "x": 161, "y": 230}
# {"numero": 3, "x": 305, "y": 320}
# {"numero": 1, "x": 444, "y": 126}
# {"numero": 2, "x": 465, "y": 208}
# {"numero": 3, "x": 282, "y": 258}
# {"numero": 3, "x": 137, "y": 62}
# {"numero": 3, "x": 100, "y": 36}
# {"numero": 2, "x": 399, "y": 379}
# {"numero": 1, "x": 468, "y": 71}
# {"numero": 2, "x": 131, "y": 381}
# {"numero": 2, "x": 433, "y": 394}
# {"numero": 3, "x": 163, "y": 199}
# {"numero": 1, "x": 399, "y": 496}
# {"numero": 1, "x": 273, "y": 313}
# {"numero": 3, "x": 190, "y": 95}
# {"numero": 1, "x": 466, "y": 84}
# {"numero": 1, "x": 90, "y": 184}
# {"numero": 2, "x": 42, "y": 436}
# {"numero": 2, "x": 445, "y": 256}
# {"numero": 3, "x": 418, "y": 387}
# {"numero": 1, "x": 348, "y": 172}
# {"numero": 3, "x": 9, "y": 336}
# {"numero": 1, "x": 342, "y": 87}
# {"numero": 1, "x": 301, "y": 213}
# {"numero": 3, "x": 321, "y": 255}
# {"numero": 3, "x": 99, "y": 221}
# {"numero": 3, "x": 439, "y": 311}
# {"numero": 1, "x": 167, "y": 205}
# {"numero": 1, "x": 127, "y": 150}
# {"numero": 2, "x": 158, "y": 420}
# {"numero": 3, "x": 422, "y": 269}
# {"numero": 3, "x": 81, "y": 130}
# {"numero": 3, "x": 292, "y": 472}
# {"numero": 1, "x": 350, "y": 125}
# {"numero": 2, "x": 222, "y": 299}
# {"numero": 3, "x": 42, "y": 398}
# {"numero": 1, "x": 298, "y": 190}
# {"numero": 1, "x": 90, "y": 209}
# {"numero": 1, "x": 319, "y": 336}
# {"numero": 2, "x": 155, "y": 494}
# {"numero": 1, "x": 379, "y": 269}
# {"numero": 2, "x": 276, "y": 350}
# {"numero": 3, "x": 360, "y": 142}
# {"numero": 2, "x": 384, "y": 493}
# {"numero": 3, "x": 121, "y": 67}
# {"numero": 3, "x": 113, "y": 461}
# {"numero": 2, "x": 326, "y": 259}
# {"numero": 3, "x": 202, "y": 202}
# {"numero": 1, "x": 284, "y": 21}
# {"numero": 2, "x": 368, "y": 28}
# {"numero": 1, "x": 372, "y": 408}
# {"numero": 1, "x": 498, "y": 36}
# {"numero": 1, "x": 253, "y": 248}
# {"numero": 3, "x": 333, "y": 133}
# {"numero": 2, "x": 390, "y": 254}
# {"numero": 1, "x": 246, "y": 368}
# {"numero": 1, "x": 0, "y": 46}
# {"numero": 2, "x": 297, "y": 249}
# {"numero": 1, "x": 303, "y": 33}
# {"numero": 2, "x": 497, "y": 253}
# {"numero": 3, "x": 186, "y": 125}
# {"numero": 3, "x": 496, "y": 475}
# {"numero": 2, "x": 157, "y": 229}
# {"numero": 1, "x": 460, "y": 414}
# {"numero": 3, "x": 460, "y": 304}
# {"numero": 3, "x": 27, "y": 50}
# {"numero": 3, "x": 56, "y": 402}
# {"numero": 2, "x": 197, "y": 199}
# {"numero": 1, "x": 39, "y": 2}
# {"numero": 3, "x": 403, "y": 0}
# {"numero": 2, "x": 147, "y": 38}
# {"numero": 3, "x": 151, "y": 35}
# {"numero": 1, "x": 339, "y": 192}
# {"numero": 3, "x": 127, "y": 4}
# {"numero": 3, "x": 49, "y": 464}
# {"numero": 2, "x": 429, "y": 343}
# {"numero": 2, "x": 177, "y": 400}
# {"numero": 1, "x": 471, "y": 449}
# {"numero": 1, "x": 367, "y": 488}
# {"numero": 1, "x": 295, "y": 243}
# {"numero": 1, "x": 329, "y": 390}
# {"numero": 1, "x": 340, "y": 41}
# {"numero": 3, "x": 326, "y": 232}
# {"numero": 1, "x": 42, "y": 360}
# {"numero": 1, "x": 23, "y": 261}
# {"numero": 1, "x": 309, "y": 190}
# {"numero": 3, "x": 496, "y": 367}
# {"numero": 2, "x": 234, "y": 190}
# {"numero": 3, "x": 24, "y": 57}
# {"numero": 3, "x": 168, "y": 205}
# {"numero": 2, "x": 312, "y": 386}
# {"numero": 1, "x": 346, "y": 226}
# {"numero": 1, "x": 416, "y": 52}
# {"numero": 2, "x": 29, "y": 446}
# {"numero": 1, "x": 147, "y": 470}
# {"numero": 2, "x": 80, "y": 131}
# {"numero": 3, "x": 357, "y": 127}
# {"numero": 2, "x": 386, "y": 214}
# {"numero": 1, "x": 12, "y": 90}
# {"numero": 2, "x": 479, "y": 110}
# {"numero": 3, "x": 189, "y": 274}
# {"numero": 1, "x": 141, "y": 120}
# {"numero": 2, "x": 487, "y": 388}
# {"numero": 2, "x": 66, "y": 270}
# {"numero": 1, "x": 356, "y": 417}
# {"numero": 3, "x": 260, "y": 349}
# {"numero": 3, "x": 205, "y": 59}
# {"numero": 1, "x": 18, "y": 445}
# {"numero": 3, "x": 373, "y": 458}
# {"numero": 2, "x": 137, "y": 289}
# {"numero": 1, "x": 107, "y": 478}
# {"numero": 1, "x": 314, "y": 471}
# {"numero": 3, "x": 100, "y": 459}
# {"numero": 1, "x": 438, "y": 25}
# {"numero": 2, "x": 74, "y": 233}
# {"numero": 1, "x": 181, "y": 493}
# Socket Cerrado, finalizando!
# OK=200 ERRORES=0
